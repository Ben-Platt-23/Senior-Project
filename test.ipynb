# %%
import pandas as pd

# %%
thing = pd.read_csv('baseball_data.csv')

# %%
from pybaseball import batting_stats

# %%
data = batting_stats(2010, 2011)

# %%
data.head(5)
# Out:
#     IDfg  Season             Name Team  Age  ...  CStr%   CSW%  xBA  xSLG  xwOBA
# 17  4727    2011  Jacoby Ellsbury  BOS   27  ...  0.194  0.254  NaN   NaN    NaN
# 0   1875    2010    Josh Hamilton  TEX   29  ...  0.094  0.229  NaN   NaN    NaN
# 9   5631    2011        Matt Kemp  LAD   26  ...  0.142  0.270  NaN   NaN    NaN
# 1   1887    2011    Jose Bautista  TOR   30  ...  0.173  0.250  NaN   NaN    NaN
# 53  8370    2011   Dustin Pedroia  BOS   27  ...  0.193  0.246  NaN   NaN    NaN
#
# [5 rows x 319 columns]
