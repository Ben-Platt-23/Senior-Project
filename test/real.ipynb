# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
tp_12 = pd.read_csv('ba_obp_slg_12.csv')
tp_13 = pd.read_csv('ba_obp_slg_12.csv')
tp_14 = pd.read_csv('ba_obp_slg_12.csv')
tp_15 = pd.read_csv('ba_obp_slg_12.csv')
tp_16 = pd.read_csv('ba_obp_slg_12.csv')
tp_17 = pd.read_csv('ba_obp_slg_12.csv')
tp_18 = pd.read_csv('ba_obp_slg_12.csv')
tp_19 = pd.read_csv('ba_obp_slg_12.csv')

# %%
tp_12 = tp_12.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_12 = tp_12.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_12 = tp_12.iloc[1:, :]
tp_12.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_13 = tp_13.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_13 = tp_13.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_13 = tp_13.iloc[1:, :]
tp_13.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_14 = tp_14.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_14 = tp_14.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_14 = tp_14.iloc[1:, :]
tp_14.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_15 = tp_15.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_15 = tp_15.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_15 = tp_15.iloc[1:, :]
tp_15.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_16 = tp_16.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_16 = tp_16.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_16 = tp_16.iloc[1:, :]
tp_16.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_17 = tp_17.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_17 = tp_17.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_17 = tp_17.iloc[1:, :]
tp_17.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_18 = tp_18.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_18 = tp_18.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_18 = tp_18.iloc[1:, :]
tp_18.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
tp_19 = tp_19.rename(columns={'Batting Against':'OBA', 'Unnamed: 0':'Team', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})
tp_19 = tp_19.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])
tp_19 = tp_19.iloc[1:, :]
tp_19.head(2)
# Out:
#                    Team    OBA   OOBP   OSLG
# 1  Arizona Diamondbacks  0.261  0.317  0.415
# 2        Atlanta Braves  0.243  0.306  0.378

# %%
test2 = pd.concat([tp_12, tp_13, tp_14, tp_15, tp_16, tp_17, tp_18, tp_19], axis=0)

# %%
test2.head(50)
# Out:
#                              Team    OBA   OOBP   OSLG
# 1            Arizona Diamondbacks  0.261  0.317  0.415
# 2                  Atlanta Braves  0.243  0.306  0.378
# 3               Baltimore Orioles  0.252  0.315  0.403
# 4                  Boston Red Sox  0.262  0.331  0.428
# 5                    Chicago Cubs  0.259  0.335  0.424
# 6               Chicago White Sox   0.25  0.319  0.405
# 7                 Cincinnati Reds  0.247  0.305   0.39
# 8               Cleveland Indians  0.268  0.336   0.43
# 9                Colorado Rockies   0.29  0.357   0.47
# 10                 Detroit Tigers  0.256  0.314  0.402
# 11                 Houston Astros   0.27  0.337  0.427
# 12             Kansas City Royals   0.27  0.339  0.423
# 13  Los Angeles Angels of Anaheim  0.246   0.31  0.403
# 14            Los Angeles Dodgers  0.238   0.31  0.364
# 15                  Miami Marlins  0.263  0.327  0.399
# 16              Milwaukee Brewers  0.261  0.326  0.414
# ...

# %%
tp = test2

# %%
team_batting = pd.read_csv('team_batting_12_19.csv')

# %%
team_pitching = pd.read_csv('team_pitching_12_19.csv')

# %%
team_batting.head()
# Out:
#    Season Team    R    AVG    OBP    SLG
# 0    2019  HOU  920  0.274  0.352  0.495
# 1    2017  HOU  896  0.282  0.346  0.478
# 2    2019  MIN  939  0.270  0.338  0.494
# 3    2013  BOS  853  0.277  0.349  0.446
# 4    2016  BOS  878  0.282  0.348  0.461

# %%
team_pitching.head()
# Out:
#    Season Team    W    R
# 0    2015  STL  100  525
# 1    2014  WSN   96  555
# 2    2018  HOU  103  534
# 3    2016  CHC  103  556
# 4    2014  SEA   87  554

# %%
team_pitching = team_pitching.rename(columns={'R':'RA'})

# %%
test_p = pd.DataFrame()

# %%
test_p = pd.concat([tp, team_pitching], axis=0)

# %%
test_p.head(-50)
# Out:
#                      Team    OBA   OOBP   OSLG  Season     W     RA
# 1    Arizona Diamondbacks  0.261  0.317  0.415     NaN   NaN    NaN
# 2          Atlanta Braves  0.243  0.306  0.378     NaN   NaN    NaN
# 3       Baltimore Orioles  0.252  0.315  0.403     NaN   NaN    NaN
# 4          Boston Red Sox  0.262  0.331  0.428     NaN   NaN    NaN
# 5            Chicago Cubs  0.259  0.335  0.424     NaN   NaN    NaN
# ..                    ...    ...    ...    ...     ...   ...    ...
# 185                   COL    NaN    NaN    NaN  2017.0  87.0  757.0
# 186                   OAK    NaN    NaN    NaN  2016.0  69.0  761.0
# 187                   PHI    NaN    NaN    NaN  2019.0  81.0  794.0
# 188                   MIN    NaN    NaN    NaN  2013.0  66.0  788.0
# 189                   HOU    NaN    NaN    NaN  2012.0  55.0  794.0
#
# [446 rows x 7 columns]

# %%
test_all = pd.concat([test_p, team_batting], axis=0)

# %%
test_all.head(50)
# Out:
#                              Team    OBA   OOBP   OSLG  Season   W  RA   R  \
# 1            Arizona Diamondbacks  0.261  0.317  0.415     NaN NaN NaN NaN
# 2                  Atlanta Braves  0.243  0.306  0.378     NaN NaN NaN NaN
# 3               Baltimore Orioles  0.252  0.315  0.403     NaN NaN NaN NaN
# 4                  Boston Red Sox  0.262  0.331  0.428     NaN NaN NaN NaN
# 5                    Chicago Cubs  0.259  0.335  0.424     NaN NaN NaN NaN
# 6               Chicago White Sox   0.25  0.319  0.405     NaN NaN NaN NaN
# 7                 Cincinnati Reds  0.247  0.305   0.39     NaN NaN NaN NaN
# 8               Cleveland Indians  0.268  0.336   0.43     NaN NaN NaN NaN
# 9                Colorado Rockies   0.29  0.357   0.47     NaN NaN NaN NaN
# 10                 Detroit Tigers  0.256  0.314  0.402     NaN NaN NaN NaN
# 11                 Houston Astros   0.27  0.337  0.427     NaN NaN NaN NaN
# ...

# %%
data = test_all

# %%
data.columns
# Out:
# Index(['Team', 'OBA', 'OOBP', 'OSLG', 'Season', 'W', 'RA', 'R', 'AVG', 'OBP',
#        'SLG'],
#       dtype='object')

# %%
data = data.drop(columns=['Team', 'Season'])

# %%
data.head()
# Out:
#      OBA   OOBP   OSLG   W  RA   R  AVG  OBP  SLG
# 1  0.261  0.317  0.415 NaN NaN NaN  NaN  NaN  NaN
# 2  0.243  0.306  0.378 NaN NaN NaN  NaN  NaN  NaN
# 3  0.252  0.315  0.403 NaN NaN NaN  NaN  NaN  NaN
# 4  0.262  0.331  0.428 NaN NaN NaN  NaN  NaN  NaN
# 5  0.259  0.335  0.424 NaN NaN NaN  NaN  NaN  NaN

# %%
data.to_csv('data.csv')
