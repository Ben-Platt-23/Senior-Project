# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
team_batting = pd.read_csv('team_batting_12_19.csv')

# %%
team_batting.head()
# Out:
#    Season Team    R    AVG    OBP    SLG
# 0    2019  HOU  920  0.274  0.352  0.495
# 1    2017  HOU  896  0.282  0.346  0.478
# 2    2019  MIN  939  0.270  0.338  0.494
# 3    2013  BOS  853  0.277  0.349  0.446
# 4    2016  BOS  878  0.282  0.348  0.461

# %%
team_batting = team_batting.astype('str')

# %%
x = team_batting.loc['R']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/benplatt/Desktop/programming/github_repositories/Senior-Project/test/test.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/benplatt/Desktop/programming/github_repositories/Senior-Project/test/test.ipynb#ch0000024?line=0'>1</a> x = team_batting.loc['R']
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///opt/homebrew/lib/python3.9/site-packages/pandas/core/indexing.py?line=963'>964</a> axis = self.axis or 0
#     <a href='file:///opt/homebrew/lib/python3.9/site-packages/pandas/core/indexing.py?line=965'>966</a> maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
print(x)
# Out:
#        R
# 0    920
# 1    896
# 2    939
# 3    853
# 4    878
# ..   ...
# 235  582
# 236  589
# 237  615
# 238  535
# 239  513
#
# [240 rows x 1 columns]

# %%
team_pitching = pd.read_csv('team_pitching_12_19.csv')

# %%
team_pitching.head()
# Out:
#    Season Team    W    R
# 0    2015  STL  100  525
# 1    2014  WSN   96  555
# 2    2018  HOU  103  534
# 3    2016  CHC  103  556
# 4    2014  SEA   87  554

# %%
team_pitching = team_pitching.rename(columns={'R':'RA'})

# %%
team_pitching.head()
# Out:
#    Season Team    W   RA
# 0    2015  STL  100  525
# 1    2014  WSN   96  555
# 2    2018  HOU  103  534
# 3    2016  CHC  103  556
# 4    2014  SEA   87  554

# %%
tp_12 = pd.read_csv('ba_obp_slg_12.csv')

# %%
tp_12.head()
# Out:
#              Unnamed: 0 Batting Against Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0                    Tm              BA        OBP        SLG         NaN
# 1  Arizona Diamondbacks           0.261      0.317      0.415         NaN
# 2        Atlanta Braves           0.243      0.306      0.378         NaN
# 3     Baltimore Orioles           0.252      0.315      0.403         NaN
# 4        Boston Red Sox           0.262      0.331      0.428         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15
# ...

# %%
tp_12 = tp_12.rename(columns={'Batting Against':'OBA', 'Unnamed: 2':'OOBP', 'Unnamed: 3':'OSLG'})

# %%
tp_12 = tp_12.drop(columns=['Unnamed: 4',	'Unnamed: 5',	'Unnamed: 6',	'Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'])

# %%
tp_12 = tp_12.rename(columns={Unnamed: 0':'Team'})

# %%
tp_12_test = tp_12.iloc[1:, :]

# %%
tp_12_test = tp_12

# %%
tp_12.head(1)
# Out:
#   Team OBA OOBP OSLG
# 0   Tm  BA  OBP  SLG

# %%
tp_12 = tp_12.iloc[1:, :]

# %%
tp_12
# Out:
#                              Team    OBA   OOBP   OSLG
# 1            Arizona Diamondbacks  0.261  0.317  0.415
# 2                  Atlanta Braves  0.243  0.306  0.378
# 3               Baltimore Orioles  0.252  0.315  0.403
# 4                  Boston Red Sox  0.262  0.331  0.428
# 5                    Chicago Cubs  0.259  0.335  0.424
# 6               Chicago White Sox   0.25  0.319  0.405
# 7                 Cincinnati Reds  0.247  0.305   0.39
# 8               Cleveland Indians  0.268  0.336   0.43
# 9                Colorado Rockies   0.29  0.357   0.47
# 10                 Detroit Tigers  0.256  0.314  0.402
# 11                 Houston Astros   0.27  0.337  0.427
# 12             Kansas City Royals   0.27  0.339  0.423
# 13  Los Angeles Angels of Anaheim  0.246   0.31  0.403
# 14            Los Angeles Dodgers  0.238   0.31  0.364
# 15                  Miami Marlins  0.263  0.327  0.399
# 16              Milwaukee Brewers  0.261  0.326  0.414
# ...

# %%
team_pitching_test = team_pitching

# %%
test = pd.DataFrame()

# %%
test = test.append(team_pitching_test)
# Out:
# /var/folders/pq/93pjlp5d3j96czmt4sylp6kh0000gn/T/ipykernel_47352/2978296495.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(team_pitching_test)

# %%
test = test.append(tp_12)
# Out:
# /var/folders/pq/93pjlp5d3j96czmt4sylp6kh0000gn/T/ipykernel_47352/27972353.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(tp_12)

# %%
test = pd.concat([tp_12, team_pitching_test], axis=1)

# %%
test
# Out:
#                      Team    OBA   OOBP   OSLG  Season Team    W   RA
# 1    Arizona Diamondbacks  0.261  0.317  0.415    2014  WSN   96  555
# 2          Atlanta Braves  0.243  0.306  0.378    2018  HOU  103  534
# 3       Baltimore Orioles  0.252  0.315  0.403    2016  CHC  103  556
# 4          Boston Red Sox  0.262  0.331  0.428    2014  SEA   87  554
# 5            Chicago Cubs  0.259  0.335  0.424    2013  ATL   96  548
# ..                    ...    ...    ...    ...     ...  ...  ...  ...
# 235                   NaN    NaN    NaN    NaN    2012  COL   64  890
# 236                   NaN    NaN    NaN    NaN    2019  DET   47  915
# 237                   NaN    NaN    NaN    NaN    2017  DET   64  894
# 238                   NaN    NaN    NaN    NaN    2019  COL   71  958
# 239                   NaN    NaN    NaN    NaN    2019  BAL   54  981
#
# [240 rows x 8 columns]
